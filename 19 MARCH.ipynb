# %%
import pandas as pd

# %%
ipl=pd.read_csv('https://raw.githubusercontent.com/training-ml/Files/main/matches.csv')
ipl.head()
# Out:
#    id  season       city      date                        team1  \
# 0   1    2017  Hyderabad  05/04/17          Sunrisers Hyderabad
# 1   2    2017       Pune  06/04/17               Mumbai Indians
# 2   3    2017     Rajkot  07/04/17                Gujarat Lions
# 3   4    2017     Indore  08/04/17       Rising Pune Supergiant
# 4   5    2017  Bangalore  08/04/17  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
ipl.tail()
# Out:
#       id  season       city      date                team1  \
# 631  632    2016     Raipur  22/05/16     Delhi Daredevils
# 632  633    2016  Bangalore  24/05/16        Gujarat Lions
# 633  634    2016      Delhi  25/05/16  Sunrisers Hyderabad
# 634  635    2016      Delhi  27/05/16        Gujarat Lions
# 635  636    2016  Bangalore  29/05/16  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
ipl.shape #total number of rows and columns
# Out:
# (636, 18)

# %%
ipl.sample(n=7)
# Out:
#       id  season        city      date                        team1  \
# 181  182    2010     Kolkata  16/03/10          Chennai Super Kings
# 348  349    2012      Jaipur  01/05/12             Rajasthan Royals
# 29    30    2017   Bangalore  27/04/17  Royal Challengers Bangalore
# 428  429    2013   Bangalore  14/05/13  Royal Challengers Bangalore
# 394  395    2013      Mumbai  13/04/13               Mumbai Indians
# 504  505    2014  Chandigarh  21/05/14              Kings XI Punjab
# 485  486    2014     Cuttack  07/05/14              Kings XI Punjab
#
#                      team2          toss_winner toss_decision  result  \
# 181  Kolkata Knight Riders  Chennai Super Kings           bat  normal
# 348       Delhi Daredevils     Rajasthan Royals           bat  normal
# 29           Gujarat Lions        Gujarat Lions         field  normal
# 428        Kings XI Punjab      Kings XI Punjab         field  normal
# 394          Pune Warriors       Mumbai Indians           bat  normal
# ...

# %%
type(ipl)
# Out:
# pandas.core.frame.DataFrame

# %% [raw]
# excel_file=pd.read_excel(r'C:\Users\yoges\OneDrive\Desktop\Scores_file.xlsx',sheet_name='Sheet2')
# excel_file

# %%
excel_file=pd.read_excel(r'C:\Users\yoges\OneDrive\Desktop\Book1.xlsx',sheet_name='Sheet1')
excel_file
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7356/282130098.py in <module>
# ----> 1 excel_file=pd.read_excel(r'C:\Users\yoges\OneDrive\Desktop\Book1.xlsx',sheet_name='Sheet1')
#       2 excel_file
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
# ...

# %%
#Exporting data
ipl.to_csv('ipl_copy.csv')

# %%
ipl.to_csv((r'C:\Users\yoges\OneDrive\Desktop\ipl_copy.csv',index=False,header=True)
# Out:
#   File "C:\Users\yoges\AppData\Local\Temp/ipykernel_7356/2334903284.py", line 1
#     ipl.to_csv((r'C:\Users\yoges\OneDrive\Desktop\ipl_copy.csv',index=False,header=True)
#                                                                      ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
url = "http://www.basketball-reference.com/leagues/NBA_2015_totals.html"
BB_data=pd.read_html(url)

# %%
BB_data[0].head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
BB_data[0].shape
# Out:
# (675, 30)

# %%
BB_data[0].columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
BB_data[0][['Rk','Player','DRB']].head()
# Out:
#   Rk         Player  DRB
# 0  1     Quincy Acy  222
# 1  2   Jordan Adams   19
# 2  3   Steven Adams  324
# 3  4    Jeff Adrien   54
# 4  5  Arron Afflalo  220

# %%
BB_data[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
pd.options.display.max_rows=2

# %%
BB_data[0]
# Out:
#       Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# ..   ...           ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 674  492  Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 0    222  301   68  27  22  60  147  398
# ..   ...  ...  ...  ..  ..  ..  ...  ...
# 674  319  465  113  18  52  76  205  833
#
# [675 rows x 30 columns]
